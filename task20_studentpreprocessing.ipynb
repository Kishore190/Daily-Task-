# %%
import pandas as pd

file_name = "C:\\Users\\XNovaQ.8\\Downloads\\archive (1)\\student\\student-mat.csv"
df = pd.read_csv(file_name, sep=';')

print("--- Initial Data Info ---")
df.info()
print("\n--- Missing Values Check ---")
print(df.isnull().sum().to_string())
print("\n--- Duplicate Rows Check ---")
print(f"Number of duplicate rows: {df.duplicated().sum()}")
# Out:
# --- Initial Data Info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    object
#  1   sex         395 non-null    object
#  2   age         395 non-null    int64
#  3   address     395 non-null    object
#  4   famsize     395 non-null    object
#  5   Pstatus     395 non-null    object
#  6   Medu        395 non-null    int64
#  7   Fedu        395 non-null    int64
#  8   Mjob        395 non-null    object
#  9   Fjob        395 non-null    object
#  10  reason      395 non-null    object
#  11  guardian    395 non-null    object
#  12  traveltime  395 non-null    int64
#  13  studytime   395 non-null    int64
#  14  failures    395 non-null    int64
#  15  schoolsup   395 non-null    object
#  16  famsup      395 non-null    object
#  17  paid        395 non-null    object
# ...

# %%
binary_map = {'yes': 1, 'no': 0}
binary_cols = ['schoolsup', 'famsup', 'paid', 'activities', 'nursery', 'higher', 'internet', 'romantic']
for col in binary_cols:
    df[col] = df[col].map(binary_map)

df['sex'] = df['sex'].map({'F': 0, 'M': 1}) 
df['school'] = df['school'].map({'GP': 0, 'MS': 1})
df['address'] = df['address'].map({'U': 1, 'R': 0}) 
df['famsize'] = df['famsize'].map({'LE3': 0, 'GT3': 1}) 
df['Pstatus'] = df['Pstatus'].map({'T': 1, 'A': 0}) 
df.head()
# Out:
#    school  sex  age  address  famsize  Pstatus  Medu  Fedu     Mjob      Fjob  \
# 0     NaN  NaN   18      NaN      NaN      NaN     4     4  at_home   teacher
# 1     NaN  NaN   17      NaN      NaN      NaN     1     1  at_home     other
# 2     NaN  NaN   15      NaN      NaN      NaN     1     1  at_home     other
# 3     NaN  NaN   15      NaN      NaN      NaN     4     2   health  services
# 4     NaN  NaN   16      NaN      NaN      NaN     3     3    other     other
#
#    ... famrel freetime  goout  Dalc  Walc  health  absences  G1  G2  G3
# 0  ...      4        3      4     1     1       3         6   5   6   6
# 1  ...      5        3      3     1     1       3         4   5   5   6
# 2  ...      4        3      2     2     3       3        10   7   8  10
# 3  ...      3        2      2     1     1       5         2  15  14  15
# 4  ...      4        3      2     1     2       5         4   6  10  10
#
# [5 rows x 33 columns]

# %%
object_cols = df.select_dtypes(include=['object']).columns
print(f"\nRemaining object columns to One-Hot Encode: {list(object_cols)}")

df = pd.get_dummies(df, columns=object_cols, drop_first=True, dtype=int)
# Out:
# Remaining object columns to One-Hot Encode: ['Mjob', 'Fjob', 'reason', 'guardian']

# %%
print("\n--- DataFrame Head after Encoding ---")
print(df.head())
print("\n--- Final Data Info ---")
df.info()

df.to_csv('student-mat_preprocessed.csv', index=False)
print("\nPreprocessed data saved to 'student-mat_preprocessed.csv'")
# Out:
# --- DataFrame Head after Encoding ---
#    school  sex  age  address  famsize  Pstatus  Medu  Fedu  traveltime  \
# 0     NaN  NaN   18      NaN      NaN      NaN     4     4           2
# 1     NaN  NaN   17      NaN      NaN      NaN     1     1           1
# 2     NaN  NaN   15      NaN      NaN      NaN     1     1           1
# 3     NaN  NaN   15      NaN      NaN      NaN     4     2           1
# 4     NaN  NaN   16      NaN      NaN      NaN     3     3           1
#
#    studytime  ...  Mjob_teacher  Fjob_health  Fjob_other  Fjob_services  \
# 0          2  ...             0            0           0              0
# 1          2  ...             0            0           1              0
# 2          2  ...             0            0           1              0
# 3          3  ...             0            0           0              1
# 4          2  ...             0            0           1              0
#
#    Fjob_teacher  reason_home  reason_other  reason_reputation  \
# ...

# %%
df.head
